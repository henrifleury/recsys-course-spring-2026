# %% [markdown]
# # Week 1 Seminar
#
# A/B experiment analysis

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 454.7 kB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: contourpy>=1.0.1 in /home/qwerty/anaconda3/envs/freqtrade/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 471.9 kB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 480.4 kB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: numpy>=1.23 in /home/qwerty/anaconda3/envs/freqtrade/lib/python3.10/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /home/qwerty/anaconda3/envs/freqtrade/lib/python3.10/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in /home/qwerty/anaconda3/envs/freqtrade/lib/python3.10/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=3 in /home/qwerty/.local/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/qwerty/anaconda3/envs/freqtrade/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/qwerty/anaconda3/envs/freqtrade/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.9

# %%
import glob
from collections import namedtuple

import pandas as pd
import numpy as np
import scipy.stats as ss

import matplotlib.pyplot as plt

pd.set_option("display.precision", 3)

# %matplotlib inline

# %%
experiment = "HSTU"
#experiment = "LGBM"

# %%
# !ls ../script/tmp/botify-recommender-1
# Out:
# ls: cannot access '../script/tmp/botify-recommender-1': No such file or directory

# %%
data = pd.concat([
    pd.read_json(data_path, lines=True)
    for data_path
    in glob.glob("../script/tmp1/botify-recommender-1/data.json")
    #in glob.glob("../jupyter/data_hstu/*/data.json")
])

data["treatment"] = data["experiments"].map(lambda experiments: experiments[experiment])

# %%
data
# Out:
#       message               timestamp  user  track  time    latency  \
# 0        next 2026-04-29 20:12:31.311  3255   5091  1.00  2.011e-03
# 1        next 2026-04-29 20:12:31.314  3255   3960  0.07  8.802e-04
# 2        next 2026-04-29 20:12:31.318  3255   8162  0.07  8.588e-04
# 3        next 2026-04-29 20:12:31.321  3255   5600  0.21  8.547e-04
# 4        next 2026-04-29 20:12:31.324  3255   1347  0.09  8.755e-04
# ...       ...                     ...   ...    ...   ...        ...
# 54443    next 2026-04-29 20:17:07.342  8872   4568  0.11  8.674e-04
# 54444    next 2026-04-29 20:17:07.346  8872  12470  0.14  8.333e-04
# 54445    next 2026-04-29 20:17:07.349  8872   3511  0.13  9.780e-04
# 54446    next 2026-04-29 20:17:07.353  8872   7118  0.01  9.820e-04
# 54447    last 2026-04-29 20:17:07.356  8872   4568  0.00  6.719e-04
#
#        recommendation     experiments treatment
# 0              3960.0  {'HSTU': 'T1'}        T1
# 1              8162.0  {'HSTU': 'T1'}        T1
# 2              5600.0  {'HSTU': 'T1'}        T1
# 3              1347.0  {'HSTU': 'T1'}        T1
# 4              1611.0  {'HSTU': 'T1'}        T1
# ...               ...             ...       ...
# 54443         12470.0   {'HSTU': 'C'}         C
# 54444          3511.0   {'HSTU': 'C'}         C
# 54445          7118.0   {'HSTU': 'C'}         C
# 54446          4568.0   {'HSTU': 'C'}         C
# 54447             NaN   {'HSTU': 'C'}         C
#
# [54448 rows x 9 columns]

# %%
data.groupby("treatment").count()
# Out:
#            message  timestamp   user  track   time  latency  recommendation  \
# treatment
# C            29252      29252  29252  29252  29252    29252           26712
# T1           27597      27597  27597  27597  27597    27597           25137
#
#            experiments
# treatment
# C                29252
# T1               27597

# %%
data.groupby("treatment").count()
# Out:
#            message  timestamp   user  track   time  latency  recommendation  \
# treatment
# C            27795      27795  27795  27795  27795    27795           25281
# T1           26653      26653  26653  26653  26653    26653           24167
#
#            experiments
# treatment
# C                27795
# T1               26653

# %% [markdown]
# ## Visualize sessions

# %%
Session = namedtuple("Session", ["timestamp", "tracks", "time", "latency"])

def sessionize(user_data):
    sessions = []
    session = None
    for _, row in user_data.sort_values("timestamp").iterrows():
        if session is None:
            session = Session(row["timestamp"], 0, 0, 0)
        
        session = session._replace(
            tracks = session.tracks + 1, 
            time = session.time + row["time"],
            latency = session.latency + row["latency"] * 1000,
        )
        
        if row["message"] == "last":
            sessions.append(session._asdict())
            session = None
    return sessions

# %%
sessions = (
    data
    .groupby(["user", "treatment"])
    .apply(sessionize)
    .explode()
    .apply(pd.Series)
)

# %%
figure, ax = plt.subplots(figsize=(15, 5))
for treatment, treatment_sessions in sessions.groupby("treatment"):
    reindexed_treatment_sessions = treatment_sessions.sort_values("timestamp").reset_index()
    ax.plot(reindexed_treatment_sessions.index, reindexed_treatment_sessions["tracks"], label=treatment)
ax.legend()
pass

# %%
figure, ax = plt.subplots(figsize=(15, 5))
for treatment, treatment_sessions in sessions.groupby("treatment"):
    reindexed_treatment_sessions = treatment_sessions.sort_values("timestamp").reset_index()
    ax.plot(reindexed_treatment_sessions.index, reindexed_treatment_sessions["tracks"], label=treatment)
ax.legend()
pass

# %%
figure, ax = plt.subplots(figsize=(15, 5))
for treatment, treatment_sessions in sessions.groupby("treatment"):
    reindexed_treatment_sessions = treatment_sessions.sort_values("timestamp").reset_index()
    ax.plot(reindexed_treatment_sessions.index, reindexed_treatment_sessions["tracks"], label=treatment)
ax.legend()
pass

# %%
figure, ax = plt.subplots(figsize=(15, 5))
for treatment, treatment_sessions in sessions.groupby("treatment"):
    reindexed_treatment_sessions = treatment_sessions.sort_values("timestamp").reset_index()
    ax.plot(reindexed_treatment_sessions.index, reindexed_treatment_sessions["time"], label=treatment)
ax.legend()
pass

# %%
figure, ax = plt.subplots(figsize=(15, 5))
for treatment, treatment_sessions in sessions.groupby("treatment"):
    reindexed_treatment_sessions = treatment_sessions.sort_values("timestamp").reset_index()
    ax.plot(reindexed_treatment_sessions.index, reindexed_treatment_sessions["time"], label=treatment)
ax.legend()
pass

# %% [markdown]
# ## Analyze the experiment

# %%
user_level_data = (
  sessions
    .reset_index()
    .groupby(["user", "treatment"])
    .agg(
        {
            "timestamp": "count",
            "tracks": "sum",
            "time": "sum",
            "latency": "sum"
        }
    )
)

user_level_data["sessions"] = user_level_data["timestamp"]
user_level_data["mean_request_latency"] = user_level_data["latency"] / user_level_data["tracks"]
user_level_data["mean_tracks_per_session"] = user_level_data["tracks"] / user_level_data["sessions"]
user_level_data["mean_time_per_session"] = user_level_data["time"] / user_level_data["sessions"]

metrics = [
    "time", 
    "sessions", 
    "mean_request_latency", 
    "mean_tracks_per_session", 
    "mean_time_per_session"
]

user_level_metrics = user_level_data[metrics].copy().reset_index()

# %%
treatment_level_metrics = (
    user_level_metrics
    .groupby("treatment")[metrics]
    .agg(["count", "mean", "var"])
)

# %%
def dof(n_0, n_1, s2_0, s2_1):
    numerator = (s2_0 / n_0 + s2_1 / n_1) * (s2_0 / n_0 + s2_1 / n_1)
    denominator = s2_0 * s2_0 / n_0 / n_0 / (n_0 - 1) + s2_1 * s2_1 / n_1 / n_1 / (n_1 - 1)
    return numerator / denominator


def ci(n_0, n_1, s2_0, s2_1, alpha=0.05):
    return ss.t.ppf(1 - alpha/2, dof(n_0, n_1, s2_0, s2_1)) * np.sqrt(s2_0 / n_0 + s2_1 / n_1)


effects = []

control = [data for treatment, data in treatment_level_metrics.iterrows() if treatment == "C"][0]

for treatment, row in treatment_level_metrics.iterrows():
    if treatment == "C":
        continue
    
    for metric in metrics:
        control_mean = control[metric]["mean"]
        treatment_mean = row[metric]["mean"]
        
        effect = treatment_mean - control_mean
        conf_int = ci(
            control[metric]["count"],
            row[metric]["count"],
            control[metric]["var"],
            row[metric]["var"],
        )
        effects.append({
            "treatment": treatment,
            "metric": metric,
            "control_mean": control_mean,
            "treatment_mean": treatment_mean,
            "effect": effect / control_mean * 100,
            "lower": (effect - conf_int) / control_mean * 100,
            "upper": (effect + conf_int) / control_mean * 100,
            "significant": (effect + conf_int) * (effect - conf_int) > 0
        })

# %%
def color(value):
    return 'color:red;' if value < 0 else 'color:green;'

def background(value):
    return 'color:white;background-color:green' if value else 'color:white;background-color:red'
        

(
    pd.DataFrame(effects)[[
        "treatment", 
        "metric",
        "effect", 
        "upper", 
        "lower", 
        "control_mean", 
        "treatment_mean",
        "significant"
    ]]
    .sort_values(["metric", "treatment"], ascending=True)
    .style
    .applymap(color, subset=["effect", "upper", "lower"])
    .applymap(background, subset=["significant"])
)
# Out:
# <style type="text/css">
# #T_1b3f3_row0_col2, #T_1b3f3_row0_col4, #T_1b3f3_row1_col2, #T_1b3f3_row1_col3, #T_1b3f3_row1_col4, #T_1b3f3_row2_col2, #T_1b3f3_row2_col3, #T_1b3f3_row2_col4, #T_1b3f3_row3_col4, #T_1b3f3_row4_col2, #T_1b3f3_row4_col3, #T_1b3f3_row4_col4 {
#   color: red;
# }
# #T_1b3f3_row0_col3, #T_1b3f3_row3_col2, #T_1b3f3_row3_col3 {
#   color: green;
# }
# #T_1b3f3_row0_col7, #T_1b3f3_row3_col7 {
#   color: white;
#   background-color: red;
# }
# #T_1b3f3_row1_col7, #T_1b3f3_row2_col7, #T_1b3f3_row4_col7 {
#   color: white;
#   background-color: green;
# }
# </style>
# <table id="T_1b3f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b3f3_level0_col0" class="col_heading level0 col0" >treatment</th>
#       <th id="T_1b3f3_level0_col1" class="col_heading level0 col1" >metric</th>
#       <th id="T_1b3f3_level0_col2" class="col_heading level0 col2" >effect</th>
#       <th id="T_1b3f3_level0_col3" class="col_heading level0 col3" >upper</th>
#       <th id="T_1b3f3_level0_col4" class="col_heading level0 col4" >lower</th>
#       <th id="T_1b3f3_level0_col5" class="col_heading level0 col5" >control_mean</th>
#       <th id="T_1b3f3_level0_col6" class="col_heading level0 col6" >treatment_mean</th>
#       <th id="T_1b3f3_level0_col7" class="col_heading level0 col7" >significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b3f3_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_1b3f3_row0_col0" class="data row0 col0" >T1</td>
#       <td id="T_1b3f3_row0_col1" class="data row0 col1" >mean_request_latency</td>
#       <td id="T_1b3f3_row0_col2" class="data row0 col2" >-0.206418</td>
#       <td id="T_1b3f3_row0_col3" class="data row0 col3" >1.087307</td>
#       <td id="T_1b3f3_row0_col4" class="data row0 col4" >-1.500142</td>
#       <td id="T_1b3f3_row0_col5" class="data row0 col5" >1.053391</td>
#       <td id="T_1b3f3_row0_col6" class="data row0 col6" >1.051217</td>
#       <td id="T_1b3f3_row0_col7" class="data row0 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1b3f3_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_1b3f3_row1_col0" class="data row1 col0" >T1</td>
#       <td id="T_1b3f3_row1_col1" class="data row1 col1" >mean_time_per_session</td>
#       <td id="T_1b3f3_row1_col2" class="data row1 col2" >-8.668459</td>
#       <td id="T_1b3f3_row1_col3" class="data row1 col3" >-4.643344</td>
#       <td id="T_1b3f3_row1_col4" class="data row1 col4" >-12.693575</td>
#       <td id="T_1b3f3_row1_col5" class="data row1 col5" >6.305313</td>
#       <td id="T_1b3f3_row1_col6" class="data row1 col6" >5.758740</td>
#       <td id="T_1b3f3_row1_col7" class="data row1 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1b3f3_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_1b3f3_row2_col0" class="data row2 col0" >T1</td>
#       <td id="T_1b3f3_row2_col1" class="data row2 col1" >mean_tracks_per_session</td>
#       <td id="T_1b3f3_row2_col2" class="data row2 col2" >-4.752544</td>
#       <td id="T_1b3f3_row2_col3" class="data row2 col3" >-2.277037</td>
#       <td id="T_1b3f3_row2_col4" class="data row2 col4" >-7.228050</td>
#       <td id="T_1b3f3_row2_col5" class="data row2 col5" >11.311600</td>
#       <td id="T_1b3f3_row2_col6" class="data row2 col6" >10.774011</td>
#       <td id="T_1b3f3_row2_col7" class="data row2 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1b3f3_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_1b3f3_row3_col0" class="data row3 col0" >T1</td>
#       <td id="T_1b3f3_row3_col1" class="data row3 col1" >sessions</td>
#       <td id="T_1b3f3_row3_col2" class="data row3 col2" >1.740272</td>
#       <td id="T_1b3f3_row3_col3" class="data row3 col3" >4.433609</td>
#       <td id="T_1b3f3_row3_col4" class="data row3 col4" >-0.953065</td>
#       <td id="T_1b3f3_row3_col5" class="data row3 col5" >1.269446</td>
#       <td id="T_1b3f3_row3_col6" class="data row3 col6" >1.291538</td>
#       <td id="T_1b3f3_row3_col7" class="data row3 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1b3f3_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_1b3f3_row4_col0" class="data row4 col0" >T1</td>
#       <td id="T_1b3f3_row4_col1" class="data row4 col1" >time</td>
#       <td id="T_1b3f3_row4_col2" class="data row4 col2" >-8.423247</td>
#       <td id="T_1b3f3_row4_col3" class="data row4 col3" >-3.642282</td>
#       <td id="T_1b3f3_row4_col4" class="data row4 col4" >-13.204211</td>
#       <td id="T_1b3f3_row4_col5" class="data row4 col5" >7.985226</td>
#       <td id="T_1b3f3_row4_col6" class="data row4 col6" >7.312611</td>
#       <td id="T_1b3f3_row4_col7" class="data row4 col7" >True</td>
#     </tr>
#   </tbody>
# </table>

# %%
def color(value):
    return 'color:red;' if value < 0 else 'color:green;'

def background(value):
    return 'color:white;background-color:green' if value else 'color:white;background-color:red'
        

(
    pd.DataFrame(effects)[[
        "treatment", 
        "metric",
        "effect", 
        "upper", 
        "lower", 
        "control_mean", 
        "treatment_mean",
        "significant"
    ]]
    .sort_values(["metric", "treatment"], ascending=True)
    .style
    .applymap(color, subset=["effect", "upper", "lower"])
    .applymap(background, subset=["significant"])
)
# Out:
# <style type="text/css">
# #T_cf216_row0_col2, #T_cf216_row0_col3, #T_cf216_row3_col3 {
#   color: green;
# }
# #T_cf216_row0_col4, #T_cf216_row1_col2, #T_cf216_row1_col3, #T_cf216_row1_col4, #T_cf216_row2_col2, #T_cf216_row2_col3, #T_cf216_row2_col4, #T_cf216_row3_col2, #T_cf216_row3_col4, #T_cf216_row4_col2, #T_cf216_row4_col3, #T_cf216_row4_col4 {
#   color: red;
# }
# #T_cf216_row0_col7, #T_cf216_row3_col7 {
#   color: white;
#   background-color: red;
# }
# #T_cf216_row1_col7, #T_cf216_row2_col7, #T_cf216_row4_col7 {
#   color: white;
#   background-color: green;
# }
# </style>
# <table id="T_cf216">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf216_level0_col0" class="col_heading level0 col0" >treatment</th>
#       <th id="T_cf216_level0_col1" class="col_heading level0 col1" >metric</th>
#       <th id="T_cf216_level0_col2" class="col_heading level0 col2" >effect</th>
#       <th id="T_cf216_level0_col3" class="col_heading level0 col3" >upper</th>
#       <th id="T_cf216_level0_col4" class="col_heading level0 col4" >lower</th>
#       <th id="T_cf216_level0_col5" class="col_heading level0 col5" >control_mean</th>
#       <th id="T_cf216_level0_col6" class="col_heading level0 col6" >treatment_mean</th>
#       <th id="T_cf216_level0_col7" class="col_heading level0 col7" >significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf216_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_cf216_row0_col0" class="data row0 col0" >T1</td>
#       <td id="T_cf216_row0_col1" class="data row0 col1" >mean_request_latency</td>
#       <td id="T_cf216_row0_col2" class="data row0 col2" >0.139268</td>
#       <td id="T_cf216_row0_col3" class="data row0 col3" >1.640503</td>
#       <td id="T_cf216_row0_col4" class="data row0 col4" >-1.361967</td>
#       <td id="T_cf216_row0_col5" class="data row0 col5" >0.999666</td>
#       <td id="T_cf216_row0_col6" class="data row0 col6" >1.001058</td>
#       <td id="T_cf216_row0_col7" class="data row0 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cf216_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_cf216_row1_col0" class="data row1 col0" >T1</td>
#       <td id="T_cf216_row1_col1" class="data row1 col1" >mean_time_per_session</td>
#       <td id="T_cf216_row1_col2" class="data row1 col2" >-6.808282</td>
#       <td id="T_cf216_row1_col3" class="data row1 col3" >-2.709691</td>
#       <td id="T_cf216_row1_col4" class="data row1 col4" >-10.906874</td>
#       <td id="T_cf216_row1_col5" class="data row1 col5" >6.506355</td>
#       <td id="T_cf216_row1_col6" class="data row1 col6" >6.063384</td>
#       <td id="T_cf216_row1_col7" class="data row1 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cf216_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_cf216_row2_col0" class="data row2 col0" >T1</td>
#       <td id="T_cf216_row2_col1" class="data row2 col1" >mean_tracks_per_session</td>
#       <td id="T_cf216_row2_col2" class="data row2 col2" >-3.469170</td>
#       <td id="T_cf216_row2_col3" class="data row2 col3" >-0.942537</td>
#       <td id="T_cf216_row2_col4" class="data row2 col4" >-5.995803</td>
#       <td id="T_cf216_row2_col5" class="data row2 col5" >11.490061</td>
#       <td id="T_cf216_row2_col6" class="data row2 col6" >11.091451</td>
#       <td id="T_cf216_row2_col7" class="data row2 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cf216_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_cf216_row3_col0" class="data row3 col0" >T1</td>
#       <td id="T_cf216_row3_col1" class="data row3 col1" >sessions</td>
#       <td id="T_cf216_row3_col2" class="data row3 col2" >-2.041115</td>
#       <td id="T_cf216_row3_col3" class="data row3 col3" >0.586146</td>
#       <td id="T_cf216_row3_col4" class="data row3 col4" >-4.668375</td>
#       <td id="T_cf216_row3_col5" class="data row3 col5" >1.291120</td>
#       <td id="T_cf216_row3_col6" class="data row3 col6" >1.264767</td>
#       <td id="T_cf216_row3_col7" class="data row3 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cf216_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_cf216_row4_col0" class="data row4 col0" >T1</td>
#       <td id="T_cf216_row4_col1" class="data row4 col1" >time</td>
#       <td id="T_cf216_row4_col2" class="data row4 col2" >-9.340005</td>
#       <td id="T_cf216_row4_col3" class="data row4 col3" >-4.592058</td>
#       <td id="T_cf216_row4_col4" class="data row4 col4" >-14.087952</td>
#       <td id="T_cf216_row4_col5" class="data row4 col5" >8.334808</td>
#       <td id="T_cf216_row4_col6" class="data row4 col6" >7.556337</td>
#       <td id="T_cf216_row4_col7" class="data row4 col7" >True</td>
#     </tr>
#   </tbody>
# </table>
